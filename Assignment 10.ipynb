# %% [markdown]
# ## ***1.Display Top 10 Rows of The Dataset***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('adult.csv')
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# ## ***2. Check Last 10 Rows of The Dataset***

# %%
df.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# ## ***3. Find Shape of Our Dataset (Number of Rows And Number of Columns)***

# %%
df.shape
# Out:
# (48842, 15)

# %% [markdown]
# ## ***4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement***

# %%
# Get the shape of the dataset
total_rows, total_columns = df.shape
print(f'Total Number of Rows: {total_rows}')
print(f'Total Number of Columns: {total_columns}')

# Get data types of each column
data_types = df.dtypes
print('\nData Types of Each Column:')
print(data_types)

# Get memory usage of the dataset
memory_usage = df.memory_usage(deep=True)
print('\nMemory Requirement of Each Column:')
print(memory_usage)

# Total memory usage
total_memory = memory_usage.sum()
print(f'\nTotal Memory Usage: {total_memory} bytes')
# Out:
# Total Number of Rows: 48842
# Total Number of Columns: 15
#
# Data Types of Each Column:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object
#
# Memory Requirement of Each Column:
# Index                  132
# age                 390736
# workclass          3168423
# fnlwgt              390736
# education          3195345
# educational-num     390736
# marital-status     3487614
# occupation         3379231
# relationship       3230347
# race               3054061
# gender             3011746
# capital-gain        390736
# capital-loss        390736
# hours-per-week      390736
# ...

# %% [markdown]
# ## ***5.Check Null Values And Also Create A Heatmap In The Dataset***

# %%
# Check for null values
null_values = df.isnull().sum()
print('Null Values in Each Column:')
print(null_values[null_values > 0])  # Display only columns with null values

# Create a heatmap for null values
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Heatmap of Null Values')
plt.show()
# Out:
# Null Values in Each Column:
# Series([], dtype: int64)

# %% [markdown]
# ## ***6. Fetch Random Sample From the Dataset (50%)***

# %%
# Fetching a random sample (50%)
random_sample = df.sample(frac=0.5, random_state=42)  # random_state for reproducibility
random_sample
# Out:
#        age         workclass  fnlwgt   education  educational-num  \
# 7762    56           Private   33115     HS-grad                9
# 23881   25           Private  112847     HS-grad                9
# 30507   43           Private  170525   Bachelors               13
# 28911   32           Private  186788     HS-grad                9
# 19484   39           Private  277886   Bachelors               13
# ...    ...               ...     ...         ...              ...
# 18837   55           Private  320835   Bachelors               13
# 37171   35  Self-emp-not-inc  170174     HS-grad                9
# 18234   21           Private  165475     HS-grad                9
# 27814   24           Private  173679   Assoc-voc               11
# 41169   54           Private  103580  Assoc-acdm               12
#
#            marital-status         occupation   relationship   race  gender  \
# 7762             Divorced      Other-service      Unmarried  White  Female
# ...

# %% [markdown]
# ## ***7. Perform Data Cleaning [Replace'?' with NaN]***

# %%
# Replace '?' with NaN
df.replace('?', np.nan, inplace=True)

# Check the dataset after cleaning
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
# ## ***8. Drop All The Missing Values***

# %%
# Dropping all rows with missing values
df.dropna(inplace=True)

# Check the dataset after dropping missing values
df.shape  # Display the new shape of the DataFrame
df.head()  # Display the first few rows of the cleaned dataset
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
# ...

# %% [markdown]
# ## ***9. Check Duplicate Data and Drop Them***

# %%
# Check for duplicate rows
duplicate_count = df.duplicated().sum()
print(f'Total Duplicate Rows: {duplicate_count}')

# Dropping duplicate rows
df.drop_duplicates(inplace=True)

# Check the dataset after dropping duplicates
df.shape  # Display the new shape of the DataFrame
df.head()  # Display the first few rows of the cleaned dataset
# Out:
# Total Duplicate Rows: 47
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
# ...

# %% [markdown]
# ## ***10. Get Overall Statistics About The Dataframe***

# %%
# Get overall statistics about the DataFrame
statistics = df.describe(include='all')  # include='all' to get statistics for all columns, including categorical
statistics
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %% [markdown]
# ## ***11. Drop The Columns education-num, capital-gain and capital-loss***

# %%
# Dropping the specified columns
df.drop(columns=['educational-num', 'capital-gain', 'capital-loss'], inplace=True)

# Check the dataset after dropping the columns
df.head()  # Display the first few rows of the updated dataset
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 5  United-States  <=50K

# %% [markdown]
# ## ***12. What Is The Distribution of Age Column Show In Graph?***

# %%
# # Histogram for the Age column
plt.figure(figsize=(10, 6))

sns.histplot(df['age'], bins=30, kde=True, color='blue')

plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ## ***13. Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method And Also Without Using Between Method***

# %%
# Using the between method
total_age_between = df[df['age'].between(17, 48)].shape[0]
print(f'Total number of persons having age between 17 to 48 (inclusive) using between method: {total_age_between}')
# Out:
# Total number of persons having age between 17 to 48 (inclusive) using between method: 34858

# %%
# Without using the between method
total_age_between_without = df[(df['age'] >= 17) & (df['age'] <= 48)].shape[0]
print(f'Total number of persons having age between 17 to 48 (inclusive) without using between method: {total_age_between_without}')
# Out:
# Total number of persons having age between 17 to 48 (inclusive) without using between method: 34858

# %% [markdown]
# ## ***14. What is The Distribution of Workclass Column***

# %%
# Count plot for the Workclass column
plt.figure(figsize=(10, 6))

sns.countplot(data=df, x='workclass', palette='Set2')

plt.title('Distribution of Workclass')
plt.xlabel('Workclass')
plt.ylabel('Count')

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %% [markdown]
# ## ***15. How Many Person Having Bachelors or Masters Degree***

# %%
# Count the number of people with Bachelor's or Master's degree
bachelors_count = df[df['education'] == 'Bachelors'].shape[0]
masters_count = df[df['education'] == 'Masters'].shape[0]

total_count = bachelors_count + masters_count

print(f'Total number of people with Bachelor\'s or Master\'s degree: {total_count}')
# Out:
# Total number of people with Bachelor's or Master's degree: 10072

# %% [markdown]
# ## ***16. Create A Boxplot Of The "Income" Column Against The "Age" Column, Segmented By Gender***

# %%
# Boxplot of Income against Age segmented by Gender
plt.figure(figsize=(12, 6))

sns.boxplot(data=df, x='age', y='income', hue='gender', palette='Set2')

plt.title('Boxplot of Income by Age Segmented by Gender')
plt.xlabel('Age')
plt.ylabel('Income')

plt.legend(title='Gender')
plt.show()

# %% [markdown]
# ## ***17. Replace income value [<=50k with 0 and >50k with 1]***

# %%
# Replace income values
df['income'] = df['income'].replace({'<=50K': 0, '>50K': 1})

# Alternatively, using boolean indexing
# df['income'] = df['income'].apply(lambda x: 0 if x == '<=50K' else 1)

print(df['income'].value_counts())
# Out:
# income
# 0    33973
# 1    11202
# Name: count, dtype: int64

# %% [markdown]
# ## ***18. Which Workclass getting The Highest Salary***

# %%
# Convert income to numeric values (if not already done)
# 0 for <=50K and 1 for >50K
df['income'] = df['income'].replace({'<=50K': 0, '>50K': 1})

# Calculate the average salary by workclass
highest_salary_workclass = df.groupby('workclass')['income'].mean().idxmax()
highest_salary_value = df.groupby('workclass')['income'].mean().max()

print(f'The workclass with the highest average salary is: {highest_salary_workclass} with an average salary of: {highest_salary_value:.2f}')
# Out:
# The workclass with the highest average salary is: Self-emp-inc with an average salary of: 0.55

# %% [markdown]
# ## ***19. Who Has Better Chance To Get Salary >50k Male or Female***

# %%
# Convert income to numeric values (if not already done)
df['income'] = df['income'].replace({'<=50K': 0, '>50K': 1})

# Calculate the proportion of each gender earning >50K
income_distribution = df.groupby('gender')['income'].mean()

# Calculate the chances
male_chance = income_distribution['Male']
female_chance = income_distribution['Female']

print(f"Chance of earning >50K for Males: {male_chance:.2f}")
print(f"Chance of earning >50K for Females: {female_chance:.2f}")

# Determine who has a better chance
if male_chance > female_chance:
    print("Males have a better chance of earning >50K.")
elif female_chance > male_chance:
    print("Females have a better chance of earning >50K.")
else:
    print("Both genders have the same chance of earning >50K.")
# Out:
# Chance of earning >50K for Males: 0.31
# Chance of earning >50K for Females: 0.11
# Males have a better chance of earning >50K.

# %% [markdown]
# ## ***20. Convert Workclass Column DataType To Category Datatype***

# %%
df['workclass'] = df['workclass'].astype('category')

print(df['workclass'].dtype)
# Out:
# category
